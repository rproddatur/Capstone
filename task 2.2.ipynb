# %% [markdown]
# # Univariate, Bi- Variate Analysis and Multi- Variate Analysis

# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('hr_Hiring_details_with_joining_status_LOB.csv',index_col = 0)

# %%
df.head()
# Out:
#      Candidate Ref DOJ Extended  Duration to accept offer  Notice period  \
# Sno
# 1          2110407          Yes                        14             30
# 2          2112635           No                        18             30
# 3          2112838           No                         3             45
# 4          2115021           No                        26             30
# 5          2115125          Yes                         1            120
#
#     Offered band  Pecent hike expected in CTC  Percent hike offered in CTC  \
# Sno
# 1             E2                       -20.79                        13.16
# 2             E2                        50.00                       320.00
# 3             E2                        42.84                        42.84
# 4             E2                        42.84                        42.84
# 5             E2                        42.59                        42.59
#
# ...

# %%
df.shape
# Out:
# (8995, 18)

# %%
df['Status'].unique()
# Out:
# array(['Joined', 'Not Joined'], dtype=object)

# %% [markdown]
# Extract the data where status is 'Joined' and 'Not Joined' and store it in df_Joined and df_Not_Joined respectively

# %%
df_Joined=df.loc[df['Status']=='Joined']
df_Not_Joined=df.loc[df['Status']=='Not Joined']

# %%
df_Joined.head()
# Out:
#      Candidate Ref DOJ Extended  Duration to accept offer  Notice period  \
# Sno
# 1          2110407          Yes                        14             30
# 2          2112635           No                        18             30
# 3          2112838           No                         3             45
# 4          2115021           No                        26             30
# 5          2115125          Yes                         1            120
#
#     Offered band  Pecent hike expected in CTC  Percent hike offered in CTC  \
# Sno
# 1             E2                       -20.79                        13.16
# 2             E2                        50.00                       320.00
# 3             E2                        42.84                        42.84
# 4             E2                        42.84                        42.84
# 5             E2                        42.59                        42.59
#
# ...

# %%
df_Not_Joined.head()
# Out:
#      Candidate Ref DOJ Extended  Duration to accept offer  Notice period  \
# Sno
# 13         2151180           No                       120             30
# 15         2156236          Yes                        14             30
# 16         2158703           No                        44             75
# 17         2161257           No                         7             30
# 19         2166041          Yes                        98             30
#
#     Offered band  Pecent hike expected in CTC  Percent hike offered in CTC  \
# Sno
# 13            E2                         5.26                       -60.53
# 15            E2                        50.00                       287.50
# 16            E2                        45.45                        60.00
# 17            E3                        53.85                        50.00
# 19            E2                        50.00                       165.36
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 1. UNIVARIATE Analysis

# %% [markdown]
# Plotting the data using one column from the df_Joined and df_Not_Joined dataframes

# %%
plt.plot(df_Joined['Age'],np.zeros_like(df_Joined['Age']),'*')

# %%
plt.plot(df_Not_Joined['Age'],np.zeros_like(df_Not_Joined['Age']),'*')

# %%
import seaborn as sns

# %%
df.isna().sum()
# Out:
# Candidate Ref                   0
# DOJ Extended                    0
# Duration to accept offer        0
# Notice period                   0
# Offered band                   13
# Pecent hike expected in CTC     0
# Percent hike offered in CTC     0
# Percent difference CTC          0
# Joining Bonus                   0
# Candidate relocate actual       0
# Gender                          0
# Candidate Source                0
# Rex in Yrs                      0
# Location                        0
# Age                            15
# LOB_id                          0
# Status                          0
# LOB                             0
# dtype: int64

# %% [markdown]
# Removing null values

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# Candidate Ref                  0
# DOJ Extended                   0
# Duration to accept offer       0
# Notice period                  0
# Offered band                   0
# Pecent hike expected in CTC    0
# Percent hike offered in CTC    0
# Percent difference CTC         0
# Joining Bonus                  0
# Candidate relocate actual      0
# Gender                         0
# Candidate Source               0
# Rex in Yrs                     0
# Location                       0
# Age                            0
# LOB_id                         0
# Status                         0
# LOB                            0
# dtype: int64

# %% [markdown]
# 2. BIVAIRIATE Analysis

# %% [markdown]
# Analysis between Duration to accept offer vs Notice period grouping (hue) by 'Status' using scatteplot

# %%
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
plt.title('Duration to accept offer vs Notice period(r = {0:0.2f})'.format(pearsonr(df['Duration to accept offer'],df['Notice period'])[0]))
sns.scatterplot(x="Duration to accept offer",y="Notice period",data = df,hue="Status")
# Out:
# <AxesSubplot:title={'center':'Duration to accept offer vs Notice period(r = 0.36)'}, xlabel='Duration to accept offer', ylabel='Notice period'>

# %% [markdown]
# Analysis between Duration to accept offer vs Notice period grouping (hue) by 'Candidate relocate actual' using scatteplot

# %%
plt.title('Duration to accept offer vs Notice Period(r = {0:0.2f})'.format(pearsonr(df['Duration to accept offer'],df['Notice period'])[0]))
sns.scatterplot(x="Duration to accept offer", y="Notice period",hue="Candidate relocate actual", style="Candidate relocate actual", data=df)
plt.show()

# %% [markdown]
# Analysis between Duration to accept offer vs Notice period grouping (hue) by 'Gender' using scatteplot

# %%
plt.title('mba_p vs degree_p(r = {0:0.2f})'.format(pearsonr(df['Duration to accept offer'],df['Notice period'])[0]))
sns.scatterplot(x="Duration to accept offer", y="Notice period",hue="Gender", style="Gender", data=df)
plt.show()

# %% [markdown]
# 3. MULTIVARIATE Analysis

# %%
df.isna().sum()
# Out:
# Candidate Ref                  0
# DOJ Extended                   0
# Duration to accept offer       0
# Notice period                  0
# Offered band                   0
# Pecent hike expected in CTC    0
# Percent hike offered in CTC    0
# Percent difference CTC         0
# Joining Bonus                  0
# Candidate relocate actual      0
# Gender                         0
# Candidate Source               0
# Rex in Yrs                     0
# Location                       0
# Age                            0
# LOB_id                         0
# Status                         0
# LOB                            0
# dtype: int64

# %%
df['Candidate Source'].unique()
# Out:
# array(['Agency', 'Employee Referral', 'Direct'], dtype=object)

# %% [markdown]
# using replot to separate the plot into columns. Here 'Candidate Source' has 3 categorical values so the plot is divided into 3 columns here

# %%
sns.relplot(x="Pecent hike expected in CTC",y="Percent hike offered in CTC",col="Candidate Source",hue="Status",style="Status",
            kind="scatter",data = df,size ="Status",sizes=(80,200))
plt.show()

# %% [markdown]
# plotting a pair plot for all the features

# %%
sns.pairplot(df,hue ='Candidate Source',size = 2)
plt.show()

# %% [markdown]
# # Missing values identification and treatment

# %% [markdown]
# 1. Deleting Null Values

# %%
data = pd.read_csv('hr_Hiring_details_with_joining_status_LOB.csv',index_col = 0)

# %%
data.shape
# Out:
# (8995, 18)

# %%
data.isnull().sum()
# Out:
# Candidate Ref                   0
# DOJ Extended                    0
# Duration to accept offer        0
# Notice period                   0
# Offered band                   13
# Pecent hike expected in CTC     0
# Percent hike offered in CTC     0
# Percent difference CTC          0
# Joining Bonus                   0
# Candidate relocate actual       0
# Gender                          0
# Candidate Source                0
# Rex in Yrs                      0
# Location                        0
# Age                            15
# LOB_id                          0
# Status                          0
# LOB                             0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Candidate Ref                  0
# DOJ Extended                   0
# Duration to accept offer       0
# Notice period                  0
# Offered band                   0
# Pecent hike expected in CTC    0
# Percent hike offered in CTC    0
# Percent difference CTC         0
# Joining Bonus                  0
# Candidate relocate actual      0
# Gender                         0
# Candidate Source               0
# Rex in Yrs                     0
# Location                       0
# Age                            0
# LOB_id                         0
# Status                         0
# LOB                            0
# dtype: int64

# %% [markdown]
# 2. Replacing the values

# %%
data = pd.read_csv('hr_Hiring_details_with_joining_status_LOB.csv',index_col = 0)

# %%
data.isnull().sum()
# Out:
# Candidate Ref                   0
# DOJ Extended                    0
# Duration to accept offer        0
# Notice period                   0
# Offered band                   13
# Pecent hike expected in CTC     0
# Percent hike offered in CTC     0
# Percent difference CTC          0
# Joining Bonus                   0
# Candidate relocate actual       0
# Gender                          0
# Candidate Source                0
# Rex in Yrs                      0
# Location                        0
# Age                            15
# LOB_id                          0
# Status                          0
# LOB                             0
# dtype: int64

# %% [markdown]
# impute numerical values with mean/median/mode

# %%
data['Age'].replace(np.nan,data['Age'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Candidate Ref                   0
# DOJ Extended                    0
# Duration to accept offer        0
# Notice period                   0
# Offered band                   13
# Pecent hike expected in CTC     0
# Percent hike offered in CTC     0
# Percent difference CTC          0
# Joining Bonus                   0
# Candidate relocate actual       0
# Gender                          0
# Candidate Source                0
# Rex in Yrs                      0
# Location                        0
# Age                             0
# LOB_id                          0
# Status                          0
# LOB                             0
# dtype: int64

# %% [markdown]
# impute categorical values with mode

# %%
data['Offered band']=data['Offered band'].replace(np.NaN,data['Offered band'].mode().values[0])

# %%
data.isnull().sum()
# Out:
# Candidate Ref                  0
# DOJ Extended                   0
# Duration to accept offer       0
# Notice period                  0
# Offered band                   0
# Pecent hike expected in CTC    0
# Percent hike offered in CTC    0
# Percent difference CTC         0
# Joining Bonus                  0
# Candidate relocate actual      0
# Gender                         0
# Candidate Source               0
# Rex in Yrs                     0
# Location                       0
# Age                            0
# LOB_id                         0
# Status                         0
# LOB                            0
# dtype: int64

# %% [markdown]
# 3. Droping columns having Nan value

# %%
data = pd.read_csv('hr_Hiring_details_with_joining_status_LOB.csv',index_col = 0)

# %%
data.isnull().sum()
# Out:
# Candidate Ref                   0
# DOJ Extended                    0
# Duration to accept offer        0
# Notice period                   0
# Offered band                   13
# Pecent hike expected in CTC     0
# Percent hike offered in CTC     0
# Percent difference CTC          0
# Joining Bonus                   0
# Candidate relocate actual       0
# Gender                          0
# Candidate Source                0
# Rex in Yrs                      0
# Location                        0
# Age                            15
# LOB_id                          0
# Status                          0
# LOB                             0
# dtype: int64

# %%
data.dropna(axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# Candidate Ref                  0
# DOJ Extended                   0
# Duration to accept offer       0
# Notice period                  0
# Pecent hike expected in CTC    0
# Percent hike offered in CTC    0
# Percent difference CTC         0
# Joining Bonus                  0
# Candidate relocate actual      0
# Gender                         0
# Candidate Source               0
# Rex in Yrs                     0
# Location                       0
# LOB_id                         0
# Status                         0
# LOB                            0
# dtype: int64

# %%
data.shape
# Out:
# (8995, 16)

# %% [markdown]
# 4. Droping rows having Nan value

# %%
data = pd.read_csv('hr_Hiring_details_with_joining_status_LOB.csv',index_col = 0)

# %%
data.isnull().sum()
# Out:
# Candidate Ref                   0
# DOJ Extended                    0
# Duration to accept offer        0
# Notice period                   0
# Offered band                   13
# Pecent hike expected in CTC     0
# Percent hike offered in CTC     0
# Percent difference CTC          0
# Joining Bonus                   0
# Candidate relocate actual       0
# Gender                          0
# Candidate Source                0
# Rex in Yrs                      0
# Location                        0
# Age                            15
# LOB_id                          0
# Status                          0
# LOB                             0
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Candidate Ref                  0
# DOJ Extended                   0
# Duration to accept offer       0
# Notice period                  0
# Offered band                   0
# Pecent hike expected in CTC    0
# Percent hike offered in CTC    0
# Percent difference CTC         0
# Joining Bonus                  0
# Candidate relocate actual      0
# Gender                         0
# Candidate Source               0
# Rex in Yrs                     0
# Location                       0
# Age                            0
# LOB_id                         0
# Status                         0
# LOB                            0
# dtype: int64

# %% [markdown]
# # Outlier analysis and treatment

# %% [markdown]
# # What is an outlier?
# An outlier is a data point in a data set that is distant from all other observations. A data point that lies outside the overall distribution of the dataset.
# # reason for an outlier
# Data point that falls outside of 1.5 times of an interquartile range above the 3rd quartile and below the 1st quartile
# Data point that falls outside of 3 standard deviations. we can use a z score and if the z score falls outside of 2 standard deviation
# # Various ways of finding the outlier.
# 1. Using Visualization (Boxplot)
# 2. Using z score
# 3. using the IQR interquantile range

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('hr_Hiring_details_with_joining_status_LOB.csv',index_col = 0)
data.sample(5)
# Out:
#        Candidate Ref DOJ Extended  Duration to accept offer  Notice period  \
# Sno
# 6511         2828725           No                        64             60
# 723          2155777           No                         1              0
# 5246         2565217          Yes                        12             45
# 11990        3691231           No                        28             60
# 1184         2206613          Yes                        66             75
#
#       Offered band  Pecent hike expected in CTC  Percent hike offered in CTC  \
# Sno
# 6511            E2                        66.11                        35.49
# 723             E2                        80.00                        60.00
# 5246            E2                        59.95                       179.91
# 11990           E2                        27.91                        27.91
# 1184            E2                        16.07                        16.07
#
# ...

# %%
data_outlier=data[['Candidate Ref', 'Duration to accept offer', 'Notice period',
     'Pecent hike expected in CTC', 'Percent hike offered in CTC', 'Percent difference CTC',
       'Rex in Yrs','Age']]
type(data_outlier)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Box plot

# %%
sns.boxplot(data=data_outlier,orient='h')
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are no outliers in the data

# %% [markdown]
# # Using Z score
# Formula for Z score = (Observation — Mean)/Standard Deviation
#
# z = (X — μ) / σ
